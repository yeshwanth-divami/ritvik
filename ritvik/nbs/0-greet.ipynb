# %%
# | default_exp greetings

# %%
#| export
from ritvik.__pre_init__ import cli

# %%
# | export


@cli.command()
def greet_english(user) -> None:
    """
    Greet the user.
    """
    print(f"Hello, {user}!")


@cli.command()
def greet_spanish(user) -> None:
    """
    Greet the user in Spanish.
    """
    print(f"¡Hola, {user}!")
